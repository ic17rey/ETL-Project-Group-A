# %% [markdown]
# ### ETL Project

# %%
import os
import pandas as pd
from sqlalchemy import create_engine
from config import username, password, dbhost, dbport, dbname

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
movies_path = os.path.join('Resources', 'movies.csv')
movies_df = pd.read_csv(movies_path, low_memory=False)

# %%
ratings_path = os.path.join('Resources', 'ratings.csv')
ratings_df = pd.read_csv(ratings_path)
ratings_df
# Out:
#       imdb_title_id  weighted_average_vote  total_votes  mean_vote  \
# 0         tt0000009                    5.9          154        5.9
# 1         tt0000574                    6.1          589        6.3
# 2         tt0001892                    5.8          188        6.0
# 3         tt0002101                    5.2          446        5.3
# 4         tt0002130                    7.0         2237        6.9
# ...             ...                    ...          ...        ...
# 85850     tt9908390                    5.3          398        5.5
# 85851     tt9911196                    7.7          724        7.9
# 85852     tt9911774                    7.9          265        7.8
# 85853     tt9914286                    6.4          194        9.4
# 85854     tt9914942                    6.7          102        6.8
#
#        median_vote  votes_10  votes_9  votes_8  votes_7  votes_6  ...  \
# 0              6.0        12        4       10       43       28  ...
# ...

# %% [markdown]
# ### Create database connection

# %%
connection_string = f'postgresql://{username}:{password}@{dbhost}:{dbport}/pets_db'

engine = create_engine(connection_string)
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2344         try:
# -> 2345             return fn()
#    2346         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     303         """
# --> 304         return _ConnectionFairy._checkout(self)
#     305
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...

# %% [markdown]
# ### Load DataFrames into database

# %%
movies_df.to_sql(name='movies', con=conn, if_exists='replace')
